# %% [markdown]
# # Module 6.1.4 Generate Random Latitude and Longitutdes (cont'd)
#
# # This file (WeatherPy.ipynb) was created per Module 6.1.4

# %%
# I included the text from the module as comments so I am able to make quicker references and trace back individual steps to writing code.

# %% [markdown]
# # Create Latitude and Longitude Combinations

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# In the next cell, we'll add the code that generates the latitudes and longitudes, 
# but first, hey need to be stored so that we can access them later. 

# Since we are creating arrays of latitudes and longitudes,
# we'll declare each array as a variable.



# In the next cell, add the following code that we used to generate the random latitudes.
# Also, we'll create a similar code snippet that will generate longitudes. 
# To ensure enough latitudes and longitudes, we'll start with 1,500. 
# In addition, we'll pack the latitudes (lats) and longitudes (lngs) as pairs
# by zipping them (lat_lngs) with the zip() function.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple. If there are 1,500 latitudes and longitudes, there will be 1,500 tuples of paired latitudes and longitudes, where each latitude and longitude in a tuple can be accessed by the index of 0 and 1, respectively.

# Let's practice zipping a small number of latitudes and longitudes and then unpacking the zipped tuple to see how the packing and unpacking work.

# In a new Jupyter Notebook file called API_practice.ipynb, add the following lists and pack them into the zipped tuple. Then, run the cell.

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# In a new cell, display the coordinate pairs with the following code.

# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# When we run the cell above, the output is ordered pairs of our x and y coordinates.

# %%
# Next, let's unpack our lat_lngs zip object into a list. 
# This way, we only need to create a set of random latitudes and longitudes once. 

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# NOTE
# You can only unzip a zipped tuple once before it is removed from the computer's memory.
# Make sure you unzip the latitudes and longitudes into the coordinates list before moving on.

# %%
# Now that we have our ordered pairs of latitudes and longitudes in a list, 
# we can iterate through the list of tuples and find the nearest city to those coordinates.

# %% [markdown]
# # 6.1.5 Generate Random World Cities

# %%
# With our list of random latitudes and longitudes, we'll use the coordinates in our lat_lngs tuple to find the nearest city using Python's citipy module.

# Since we haven't worked with the citipy module yet, let's import and test it. Citipy doesn't come with the Anaconda module, so we'll install it in our PythonData environment.

# %%
# The citypy documentation (https://pypi.org/project/citipy/) instructs us to install the citipy module by typing pip install citipy.

# Windows
# To install the citipy module on Windows, complete the following steps:

# 1. Click the clipboard to copy 'pip install citipy'.

# 2. Launch your PythonData Anaconda Prompt. You should see the following:

# (PythonData) C:\Users\your_computer_name>

# 3. Paste 'pip install citipy' and press Enter.

# %% [markdown]
# # Download completed (Windows)

# %%
# NOTE
# When a Python file containing a script is imported to use in another Python script, the .py extension does not need to be added to the name of the file when using the import statement.

# Let's import the citipy script and practice using it. In our API_practice file, add a new cell and import the citipy.py script from the citipy module.

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Next, use the five pairs of latitudes and longitudes we used from our zip practice to get a city and country code from the citipy module.

# In a new cell, create a for loop that will do the following:

# 1. Iterate through the coordinates' zipped tuple.
# 2. Use citipy.nearest_city() and inside the parentheses of nearest_city(), add the latitude and longitude in this format: coordinate[0], coordinate[1].
# 3. To print the city name, chain the city_name to the nearest_city() function.
# 4. To print the country name, chain the country_code to the nearest_city() function.

# Your code should look like the following. Add the code to a new cell and run the cell.

# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# vao nc
# kahului us
# marsh harbour bs
# ushuaia ar
# bredasdorp za
# jamestown sh
# twentynine palms us
# mayahi ne
# chumikan ru
# albany au
# ushuaia ar
# chaohu cn
# fortuna us
# rudbar ir
# barentsburg sj
# kushmurun kz
# yemelyanovo ru
# asau tv
# kodiak us
# rikitea pf
# pisco pe
# iquique cl
# vaini to
# puerto ayora ec
# ibra om
# mahebourg mu
# mataura pf
# cape town za
# clyde river ca
# kalundborg dk
# hilo us
# isangel vu
# rikitea pf
# sainte-martine ca
# santiago ph
# cidreira br
# iquique cl
# cherskiy ru
# rikitea pf
# busselton au
# portland au
# bilma ne
# taolanaro mg
# ust-barguzin ru
# ushuaia ar
# rikitea pf
# faanui pf
# bredasdorp za
# bredasdorp za
# pevek ru
# ziniare bf
# cape town za
# ushuaia ar
# utiroa ki
# yerbogachen ru
# atar mr
# kodiak us
# paracuru br
# barentsburg sj
# rikitea pf
# cabo san lucas mx
# new norfolk au
# shubarshi kz
# saint-joseph re
# mataura pf
# albany au
# bambous virieux mu
# mar del plata ar
# barentsburg sj
# kampot kh
# voyvozh ru
# punta arenas cl
# albany au
# baneh ir
# punta arenas cl
# ciudad bolivar ve
# peterhead gb
# sungaipenuh id
# bargal so
# ponta do sol cv
# kapaa us
# bredasdorp za
# rikitea pf
# kinanah sd
# atuona pf
# rikitea pf
# narsaq gl
# lensk ru
# zhangjiakou cn
# taolanaro mg
# ouallam ne
# bredasdorp za
# qasigiannguit gl
# rolim de moura br
# kerouane gn
# nikolskoye ru
# punta arenas cl
# mataura pf
# alofi nu
# mataura pf
# macaboboni ph
# busselton au
# sabaudia it
# marcona pe
# hermanus za
# fredericksburg us
# xiaoweizhai cn
# cayenne gf
# cairns au
# okmulgee us
# narsaq gl
# albany au

# %%
# ^^^ When we run this cell, the output will show [five???] cities with their associated country codes.

# %%
# Now that we are familiar with using the citipy module, we can iterate through our 
# zipped lat_lngs tuple and find the nearest city. When we find a city, we'll need to add it to a 
# list so that we can use the cities to get the weather data.

# First, import the citipy module in our WeatherPy file. In a new cell, add the following code.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# ^^^ (Code above): Some of this code should look familiar, but let's break it down:

# We create a cities list to store city names.
# We iterate through the coordinates, as in our practice, and retrieve the nearest city using the latitude and longitude pair.
# We add a decision statement with the logical operator not in to determine whether the found city is already in the cities list. 
    # If not, then we'll use the append() function to add it. We are doing this because among the 1,500 latitudes and longitudes, 
    # there might be duplicates, which will retrieve duplicate cities, and we want to be sure we capture only the unique cities.
# Out:
# 656

# %%
# NOTE
# The citipy module finds the nearest city to the latitude and longitude pair with a population of 500 or more.

# FINDING
# When you run the code block, you should get slightly more than 500 unique cities. If you get fewer than 500, increase your size limit on the np.random.uniform() function.

# %% [markdown]
# # 6.2.1 Understanding APIs

# %%
# When a client uses our company's website to search for hotels, 
# our search engine will gather information from a variety of websites based on the client's preferences through APIs. 
# An API call is very similar to navigating to a website. 
# An API points to a URL and collects some data from the webpage or server.

# When clients request information from our server through our website,
# they are making an API call. Once our database has the client's search criteria, 
# our servers search the web for hotels on behalf of the client. 
# Now the roles are reversed: our company is the client requesting information,
# and all the websites where we derive information are the servers.

# Using an API has its limitations because not all information from a server is accessible. 
# Most APIs have tiered services, from free to paid. Free services allow access to limited information,
# and paid subscriptions provide more access based on the payment plan. Our company has a paid subscription 
# for APIs, but we can only get certain information from websites on hotels such as location, accessibility,
# rooms, prices, services, and amenities, as well as regional weather data.

# Now that you have a general concept of how APIs work, let's register for an OpenWeatherMap API key,
# a token granting access, and use it to retrieve weather data.

# %% [markdown]
# # 6.2.2 Get Started with OpenWeatherMap API

# %%
# Register for an API key, then review a short example of how to retrieve weather data from an API call.

# Register for an API Key
# Follow these steps to register for an OpenweatherMap API key:

# Navigate to the OpenWeatherMap website (Links to an external site.).

# Click "sign up."

# The login/sign-up page for the OpenWeatherMap API

# Complete the form Create New Account.

# The "Create New Account" page for the OpenWeatherMap API, requesting a username, email, and password, which must be entered twice

# Once you have a new account, sign in and click on "API keys."

# The options page for the OpenWeatherMap API, with an arro pointing to the "API keys tab

# The site will likely generate an API key automatically. If not, under "Create key," type a name in the available cell and click "Generate" to create an API key.

# The screen where you create an API key on the OpenWeatherMap API webpage with the "Key" field and the "Generate" button shown

# Save your API key to a Python file, which we'll add as a dependency to your WeatherPy.ipynb file.

# Navigate to your World_Weather_Analysis folder and launch Jupyter Notebook.
# Click the New button and select Text File.
# Rename the text file config.py.
# On the first line, type weather_api_key="" and add your API key between the double quotation marks.
# Save and close the config.py file.
# NOTE
# You can also create the config.py file using VS Code.

# IMPORTANT
# Don't share your API key with anyone, and do not add the config.py file to your GitHub repository–someone might copy and use it, and you could incur charges on your credit card.

# Click on "Services" for details on your free subscription and its limitations.

# The "Services" tab on the menu showing the free plan services for the OpenWeatherMap API

# Click on "View" to see more options on your plan, and then click on "Current weather API" to see how to get the current weather from a city.

# data-6-2-2-6-API_Current_weather.png

# We'll refer to this documentation when we make an API call to the server.

# The JavaScript Object Notation Format for API Data
# The API has reached the website or server, its endpoint, and now we can retrieve data from the website. When we retrieve data from a website, we have to make a "request," which returns data in a text format, not in a tab- or comma-separated file.

# One format we can use to parse data is JavaScript Object Notation (JSON). The JSON format is also referred to as an "object" or "JSON object." The data inside a JSON object opens and closes with curly braces, much like a Python dictionary. Inside the JSON object is a collection of dictionaries and arrays.

# Below is an example of what weather data looks like in the JSON format when we request it from the OpenWeatherMap website. There are curly braces that wrap the data, and inside the curly braces are dictionaries and arrays.

# Weather data in the JSON format has curly braces.

# The Python Requests Library
# To request JSON data over the internet, we use the Requests Library in Python. The Anaconda installation comes with version 2.22 of the Requests Library.

# Confirm you have the latest version of the Requests Library using the command line, or in the Jupyter Notebook environment. Follow the instructions for your operating system.

# Check out the macOS instructions below, or jump to the Windows instructions.

# MAC -deleted-

# Windows
# Launch the Anaconda Prompt for your PythonData environment.
# After the Python prompt, >, type python to launch Python.
# At the Python prompt, >>>, type import requests and press Enter.
# On the next line type requests.__version__ and press Enter.
# The output should be version 2.22.0 or later.
# Alternatively, you can check the version of request in Jupyter Notebook.

# In Jupyter Notebook, create a new file if one hasn't been created. Add the following code to the new cell and run it.

# import requests
# requests.__version__
# The output should be 2.22.0 or later.

# If you have an older version, please upgrade it in your PythonData environment by typing conda install -c conda-forge requests, at the command prompt and press Enter.

# NOTE
# For more information about the Requests Library, see the following documentation:

# Requests: HTTP for Humans (Links to an external site.)
# https://requests.kennethreitz.org/en/master/

# Quickstart
# https://requests.kennethreitz.org/en/master/user/quickstart/#make-a-request

# %% [markdown]
# # 6.2.6 Get the City Weather Data

# %%
# Let's use pseudocode to map out, at a high level, how we will get the weather data for each city for the website.

# We will need to do the following:

# 1. Import our dependencies and initialize counters and an empty list that will hold the weather data.
# 2. Loop through the cities list.
# 3. Group the cities in sets of 50 to log the process as we find the weather data for each city.
    # Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# 4. Build the city_url or endpoint for each city.
# 5. Log the URL and the record and set numbers.
# 6. ake an API request for each city.
# 7. Parse the JSON weather data for the following:
    # City, country, and date
    # Latitude and longitude
    # Maximum temperature
    # Humidity
    # Cloudiness
    # Wind speed
# 8. Add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %%
# Import Dependencies, and Initialize an Empty List and Counters

# At the top of our code block, we are going to declare an empty list, city_data = []; add a print statement that references the beginning of the logging; and create counters for the record numbers, 1–50; and the set counter.

# We will now work in our WeatherPy.ipynb file. Before continuing, make sure the following tasks are completed:

# Import your Requests Library 
import requests

# Import the weather_api_key
from config import weather_api_key

# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# ^^^ Url from Module 6.2.3: Make an API Call--refer to code in API_Practice.ipynb

# Also, import the time library, as well as the datetime module using the following code:

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# ^^^ Above: In the code block, we have initialized the counters at 1 because we want the first iteration of the logging for each recorded response and the set to start at 1.


# Loop Through the List of Cities and Build the City URL
# Next, we need to iterate through our list of cities and begin building the URL for each city, while grouping our records in sets of 50. To do this, use for i in range(len(cities)) and the index to tell us when we get to 50. Once we get to 50, we tell the program to pause for 60 seconds using the time.sleep(60) command. The OpenWeatherMap API only allows 60 calls for per minute on their free tier, so pausing our program for one minute after each set of 50 will prevent time-out errors. We can also retrieve the city from the cities list and add it to the city_url by using indexing, as shown in the following code:


# Every time we want to reference the city in our code, we need to use the indexing on the cities list. Unfortunately, this will cause programming errors when we are building the city_url because it adds the index, not the city name, to the city_url. To fix this issue, we need to create another for loop to get the city from the cities list.
# Instead of using two for loops, we can use the enumerate() method as an alternative way to iterate through the list of cities and retrieve both the index, and the city from the list. The syntax for the enumerate() method is the following:
# for i, item in enumerate(list):
# Let's use the enumerate() method to get the index of the city for logging purposes and the city for creating an endpoint URL. Add the following code below our counters.

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Handle API Request Errors with try-except Blocks
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | omboue
# Processing Record 2 of Set 1 | khandyga
# Processing Record 3 of Set 1 | puerto del rosario
# Processing Record 4 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 5 of Set 1 | berlevag
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | bengkulu
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | caravelas
# Processing Record 12 of Set 1 | torbay
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | chenzhou
# Processing Record 15 of Set 1 | vienna
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | salinopolis
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | sao joao da barra
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | lourdes
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | fayaoue
# Processing Record 32 of Set 1 | erzin
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | capinopolis
# Processing Record 35 of Set 1 | grasse
# Processing Record 36 of Set 1 | terme
# Processing Record 37 of Set 1 | calafell
# Processing Record 38 of Set 1 | trogir
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | kawalu
# Processing Record 42 of Set 1 | ati
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | huilong
# Processing Record 45 of Set 1 | yerbogachen
# Processing Record 46 of Set 1 | rocha
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | lulea
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | raymondville
# Processing Record 3 of Set 2 | pacific grove
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | dombarovskiy
# Processing Record 7 of Set 2 | collie
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | raudeberg
# Processing Record 11 of Set 2 | iskateley
# Processing Record 12 of Set 2 | tamiahua
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | kuruman
# Processing Record 16 of Set 2 | cabedelo
# Processing Record 17 of Set 2 | meadow lake
# Processing Record 18 of Set 2 | srandakan
# Processing Record 19 of Set 2 | zhezkazgan
# Processing Record 20 of Set 2 | mwinilunga
# Processing Record 21 of Set 2 | kathu
# Processing Record 22 of Set 2 | codrington
# Processing Record 23 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 2 | banes
# Processing Record 25 of Set 2 | hithadhoo
# Processing Record 26 of Set 2 | chernyshevskiy
# Processing Record 27 of Set 2 | port-cartier
# Processing Record 28 of Set 2 | arawa
# Processing Record 29 of Set 2 | mataram
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | martapura
# Processing Record 32 of Set 2 | kambove
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | adrar
# Processing Record 35 of Set 2 | nome
# Processing Record 36 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 2 | chiang kham
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | helong
# Processing Record 40 of Set 2 | portland
# Processing Record 41 of Set 2 | ndele
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | mirina
# City not found. Skipping...
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | krasnoselkup
# Processing Record 47 of Set 2 | hobart
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | rikitea
# Processing Record 50 of Set 2 | shakawe
# Processing Record 1 of Set 3 | cayenne
# Processing Record 2 of Set 3 | seydi
# Processing Record 3 of Set 3 | oussouye
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | munirabad
# Processing Record 6 of Set 3 | ajaccio
# Processing Record 7 of Set 3 | shirokiy
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | kiama
# Processing Record 12 of Set 3 | kupang
# Processing Record 13 of Set 3 | pangkalanbuun
# Processing Record 14 of Set 3 | ossora
# Processing Record 15 of Set 3 | lorengau
# Processing Record 16 of Set 3 | cockburn town
# Processing Record 17 of Set 3 | bluff
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | arraial do cabo
# Processing Record 20 of Set 3 | chapais
# Processing Record 21 of Set 3 | iwanai
# Processing Record 22 of Set 3 | college
# Processing Record 23 of Set 3 | mahebourg
# Processing Record 24 of Set 3 | saint-philippe
# Processing Record 25 of Set 3 | sri aman
# Processing Record 26 of Set 3 | elbistan
# Processing Record 27 of Set 3 | belchertown
# Processing Record 28 of Set 3 | camacupa
# Processing Record 29 of Set 3 | new norfolk
# Processing Record 30 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 3 | hasaki
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | palana
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | hohhot
# Processing Record 36 of Set 3 | belmonte
# Processing Record 37 of Set 3 | maridi
# Processing Record 38 of Set 3 | liverpool
# Processing Record 39 of Set 3 | alindao
# Processing Record 40 of Set 3 | naze
# Processing Record 41 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 3 | harbour breton
# Processing Record 43 of Set 3 | abha
# Processing Record 44 of Set 3 | kimbe
# Processing Record 45 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 3 | masvingo
# Processing Record 47 of Set 3 | qena
# Processing Record 48 of Set 3 | kilindoni
# Processing Record 49 of Set 3 | maybole
# Processing Record 50 of Set 3 | ciudad bolivar
# Processing Record 1 of Set 4 | korla
# Processing Record 2 of Set 4 | alofi
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | namibe
# Processing Record 5 of Set 4 | lopatyn
# Processing Record 6 of Set 4 | paita
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | nakasongola
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | bandarbeyla
# Processing Record 12 of Set 4 | troitsko-pechorsk
# Processing Record 13 of Set 4 | leh
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | tiarei
# Processing Record 16 of Set 4 | neryungri
# Processing Record 17 of Set 4 | guane
# Processing Record 18 of Set 4 | paamiut
# Processing Record 19 of Set 4 | ostrovnoy
# Processing Record 20 of Set 4 | waddan
# Processing Record 21 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 4 | yumen
# Processing Record 23 of Set 4 | osorno
# Processing Record 24 of Set 4 | provideniya
# Processing Record 25 of Set 4 | pestravka
# Processing Record 26 of Set 4 | chara
# Processing Record 27 of Set 4 | grindavik
# Processing Record 28 of Set 4 | gizo
# Processing Record 29 of Set 4 | saskylakh
# Processing Record 30 of Set 4 | chokurdakh
# Processing Record 31 of Set 4 | turukhansk
# Processing Record 32 of Set 4 | altay
# Processing Record 33 of Set 4 | konevo
# Processing Record 34 of Set 4 | libertador general san martin
# Processing Record 35 of Set 4 | poum
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | bukama
# Processing Record 38 of Set 4 | puerto ayora
# Processing Record 39 of Set 4 | barcelona
# Processing Record 40 of Set 4 | maldonado
# Processing Record 41 of Set 4 | saint george
# Processing Record 42 of Set 4 | bardiyah
# Processing Record 43 of Set 4 | maceio
# Processing Record 44 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 4 | narsaq
# Processing Record 46 of Set 4 | talnakh
# Processing Record 47 of Set 4 | olmos
# Processing Record 48 of Set 4 | komsomolskiy
# Processing Record 49 of Set 4 | manzhouli
# Processing Record 50 of Set 4 | tabas
# Processing Record 1 of Set 5 | yar-sale
# Processing Record 2 of Set 5 | havoysund
# Processing Record 3 of Set 5 | hargeysa
# Processing Record 4 of Set 5 | manaure
# Processing Record 5 of Set 5 | lokoja
# Processing Record 6 of Set 5 | moron
# Processing Record 7 of Set 5 | baoqing
# Processing Record 8 of Set 5 | wamba
# Processing Record 9 of Set 5 | salalah
# Processing Record 10 of Set 5 | rawson
# Processing Record 11 of Set 5 | sinop
# Processing Record 12 of Set 5 | gilgit
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | nouadhibou
# Processing Record 15 of Set 5 | kruisfontein
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | susanville
# Processing Record 18 of Set 5 | niamey
# Processing Record 19 of Set 5 | chazuta
# Processing Record 20 of Set 5 | los llanos de aridane
# Processing Record 21 of Set 5 | sitka
# Processing Record 22 of Set 5 | saint-augustin
# Processing Record 23 of Set 5 | jacareacanga
# Processing Record 24 of Set 5 | aasiaat
# Processing Record 25 of Set 5 | tuatapere
# Processing Record 26 of Set 5 | dingle
# Processing Record 27 of Set 5 | ozernovskiy
# Processing Record 28 of Set 5 | saint-joseph
# Processing Record 29 of Set 5 | avarua
# Processing Record 30 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 5 | altamira
# Processing Record 32 of Set 5 | carnarvon
# Processing Record 33 of Set 5 | pafos
# Processing Record 34 of Set 5 | sun city west
# Processing Record 35 of Set 5 | port lincoln
# Processing Record 36 of Set 5 | olafsvik
# Processing Record 37 of Set 5 | katsuura
# Processing Record 38 of Set 5 | kaitangata
# Processing Record 39 of Set 5 | saint-georges
# Processing Record 40 of Set 5 | lacolle
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5 | ajdabiya
# Processing Record 43 of Set 5 | bairiki
# Processing Record 44 of Set 5 | puerto leguizamo
# Processing Record 45 of Set 5 | aden
# Processing Record 46 of Set 5 | beipiao
# Processing Record 47 of Set 5 | madimba
# Processing Record 48 of Set 5 | hilo
# Processing Record 49 of Set 5 | kyra
# Processing Record 50 of Set 5 | souillac
# Processing Record 1 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 6 | tuim
# Processing Record 3 of Set 6 | lompoc
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | chuy
# Processing Record 6 of Set 6 | seoul
# Processing Record 7 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 6 | perth
# Processing Record 9 of Set 6 | labuhan
# Processing Record 10 of Set 6 | ous
# Processing Record 11 of Set 6 | samarai
# Processing Record 12 of Set 6 | mtambile
# Processing Record 13 of Set 6 | mahajanga
# Processing Record 14 of Set 6 | vidalia
# Processing Record 15 of Set 6 | kizukuri
# Processing Record 16 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 17 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 18 of Set 6 | kotelnikovo
# Processing Record 19 of Set 6 | asau
# Processing Record 20 of Set 6 | svetlaya
# Processing Record 21 of Set 6 | aklavik
# Processing Record 22 of Set 6 | karimnagar
# Processing Record 23 of Set 6 | dwarka
# Processing Record 24 of Set 6 | kholodnyy
# Processing Record 25 of Set 6 | port augusta
# Processing Record 26 of Set 6 | isangel
# Processing Record 27 of Set 6 | kimberley
# Processing Record 28 of Set 6 | husavik
# Processing Record 29 of Set 6 | pevek
# Processing Record 30 of Set 6 | vila do maio
# Processing Record 31 of Set 6 | bambanglipuro
# Processing Record 32 of Set 6 | vostok
# Processing Record 33 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | puerto suarez
# Processing Record 36 of Set 6 | coquimbo
# Processing Record 37 of Set 6 | esperance
# Processing Record 38 of Set 6 | griffith
# Processing Record 39 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 6 | rameshki
# Processing Record 42 of Set 6 | shenjiamen
# Processing Record 43 of Set 6 | lagoa
# Processing Record 44 of Set 6 | ginir
# Processing Record 45 of Set 6 | general roca
# Processing Record 46 of Set 6 | tolaga bay
# Processing Record 47 of Set 6 | banda aceh
# Processing Record 48 of Set 6 | kasongo
# Processing Record 49 of Set 6 | rupert
# Processing Record 50 of Set 6 | dickson
# Processing Record 1 of Set 7 | mahaicony
# City not found. Skipping...
# Processing Record 2 of Set 7 | taltal
# Processing Record 3 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 7 | cap malheureux
# Processing Record 5 of Set 7 | jos
# Processing Record 6 of Set 7 | aykhal
# Processing Record 7 of Set 7 | zhigalovo
# Processing Record 8 of Set 7 | skiros
# City not found. Skipping...
# Processing Record 9 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 7 | katsiveli
# City not found. Skipping...
# Processing Record 11 of Set 7 | mishan
# Processing Record 12 of Set 7 | jijiga
# Processing Record 13 of Set 7 | havelock
# Processing Record 14 of Set 7 | papar
# Processing Record 15 of Set 7 | saint-pierre
# Processing Record 16 of Set 7 | ulaangom
# Processing Record 17 of Set 7 | prado
# Processing Record 18 of Set 7 | hami
# Processing Record 19 of Set 7 | paragominas
# Processing Record 20 of Set 7 | sept-iles
# Processing Record 21 of Set 7 | kirksville
# Processing Record 22 of Set 7 | likasi
# Processing Record 23 of Set 7 | dongkan
# Processing Record 24 of Set 7 | susner
# Processing Record 25 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 7 | peleduy
# Processing Record 27 of Set 7 | pochutla
# Processing Record 28 of Set 7 | ambulu
# Processing Record 29 of Set 7 | agirish
# Processing Record 30 of Set 7 | los zacatones
# Processing Record 31 of Set 7 | vardo
# Processing Record 32 of Set 7 | dongsheng
# Processing Record 33 of Set 7 | constitucion
# Processing Record 34 of Set 7 | bilma
# Processing Record 35 of Set 7 | the valley
# Processing Record 36 of Set 7 | pangai
# Processing Record 37 of Set 7 | anqing
# Processing Record 38 of Set 7 | guicheng
# City not found. Skipping...
# Processing Record 39 of Set 7 | san patricio
# Processing Record 40 of Set 7 | fairbanks
# Processing Record 41 of Set 7 | teeli
# Processing Record 42 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set
of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 9 | dovers
# Processing Record 27 of Set 9 | inta
# Processing Record 28 of Set 9 | ploemeur
# Processing Record 29 of Set 9 | beira
# Processing Record 30 of Set 9 | egvekinot
# Processing Record 31 of Set 9 | gouyave
# Processing Record 32 of Set 9 | sao filipe
# Processing Record 33 of Set 9 | baghdad
# Processing Record 34 of Set 9 | lima
# Processing Record 35 of Set 9 | fallon
# Processing Record 36 of Set 9 | staryy nadym
# Processing Record 37 of Set 9 | atherton
# Processing Record 38 of Set 9 | besikduzu
# Processing Record 39 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 9 | tanout
# Processing Record 41 of Set 9 | port macquarie
# Processing Record 42 of Set 9 | mokhsogollokh
# Processing Record 43 of Set 9 | cumana
# Processing Record 44 of Set 9 | ruteng
# Processing Record 45 of Set 9 | ciro marina
# Processing Record 46 of Set 9 | hokitika
# Processing Record 47 of Set 9 | mundo nuevo
# Processing Record 48 of Set 9 | camacha
# Processing Record 49 of Set 9 | krasnogorskoye
# Processing Record 50 of Set 9 | lafiagi
# Processing Record 1 of Set 10 | baghmara
# Processing Record 2 of Set 10 | raahe
# Processing Record 3 of Set 10 | bell ville
# Processing Record 4 of Set 10 | novikovo
# Processing Record 5 of Set 10 | barahona
# Processing Record 6 of Set 10 | westport
# Processing Record 7 of Set 10 | namikupa
# Processing Record 8 of Set 10 | frutal
# Processing Record 9 of Set 10 | vigrestad
# Processing Record 10 of Set 10 | kars
# Processing Record 11 of Set 10 | trincomalee
# Processing Record 12 of Set 10 | tilichiki
# Processing Record 13 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 10 | ust-ilimsk
# Processing Record 15 of Set 10 | satuk
# Processing Record 16 of Set 10 | baisha
# Processing Record 17 of Set 10 | kloulklubed
# Processing Record 18 of Set 10 | calama
# Processing Record 19 of Set 10 | rucheng
# Processing Record 20 of Set 10 | mayumba
# Processing Record 21 of Set 10 | sterling
# Processing Record 22 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 23 of Set 10 | sabang
# Processing Record 24 of Set 10 | price
# Processing Record 25 of Set 10 | kamenka
# Processing Record 26 of Set 10 | enshi
# Processing Record 27 of Set 10 | yinchuan
# Processing Record 28 of Set 10 | kavaratti
# Processing Record 29 of Set 10 | chifeng
# Processing Record 30 of Set 10 | celestun
# Processing Record 31 of Set 10 | lovozero
# Processing Record 32 of Set 10 | galesong
# Processing Record 33 of Set 10 | great falls
# Processing Record 34 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 36 of Set 10 | natal
# Processing Record 37 of Set 10 | sinnamary
# Processing Record 38 of Set 10 | wairoa
# Processing Record 39 of Set 10 | daru
# Processing Record 40 of Set 10 | malkangiri
# Processing Record 41 of Set 10 | cabo san lucas
# Processing Record 42 of Set 10 | sena madureira
# Processing Record 43 of Set 10 | karwar
# Processing Record 44 of Set 10 | eyl
# Processing Record 45 of Set 10 | iqaluit
# Processing Record 46 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 47 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 10 | shitanjing
# Processing Record 49 of Set 10 | bogo
# Processing Record 50 of Set 10 | mareeba
# Processing Record 1 of Set 11 | raga
# Processing Record 2 of Set 11 | kazanskoye
# Processing Record 3 of Set 11 | vilyuysk
# Processing Record 4 of Set 11 | rivadavia
# Processing Record 5 of Set 11 | abyek
# Processing Record 6 of Set 11 | sarangani
# Processing Record 7 of Set 11 | nam tha
# City not found. Skipping...
# Processing Record 8 of Set 11 | kuala terengganu
# Processing Record 9 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 11 | ribnitz-damgarten
# Processing Record 11 of Set 11 | kisangani
# Processing Record 12 of Set 11 | erenhot
# Processing Record 13 of Set 11 | sabalgarh
# Processing Record 14 of Set 11 | evensk
# Processing Record 15 of Set 11 | muzhi
# Processing Record 16 of Set 11 | martinsburg
# Processing Record 17 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 11 | constantine
# Processing Record 19 of Set 11 | ambon
# Processing Record 20 of Set 11 | tura
# Processing Record 21 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 22 of Set 11 | gat
# Processing Record 23 of Set 11 | son la
# Processing Record 24 of Set 11 | lazaro cardenas
# Processing Record 25 of Set 11 | diamantino
# Processing Record 26 of Set 11 | nikki
# Processing Record 27 of Set 11 | bobo dioulasso
# Processing Record 28 of Set 11 | mayo
# Processing Record 29 of Set 11 | praia
# Processing Record 30 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 11 | syracuse
# Processing Record 32 of Set 11 | adelaide
# Processing Record 33 of Set 11 | tokmak
# Processing Record 34 of Set 11 | mehamn
# Processing Record 35 of Set 11 | bud
# Processing Record 36 of Set 11 | hobyo
# Processing Record 37 of Set 11 | saint-louis
# Processing Record 38 of Set 11 | tabou
# Processing Record 39 of Set 11 | boyolangu
# Processing Record 40 of Set 11 | carutapera
# Processing Record 41 of Set 11 | sorada
# Processing Record 42 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 43 of Set 11 | te anau
# Processing Record 44 of Set 11 | trairi
# Processing Record 45 of Set 11 | nuuk
# Processing Record 46 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 47 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 11 | markivka
# Processing Record 49 of Set 11 | mangai
# Processing Record 50 of Set 11 | kerouane
# Processing Record 1 of Set 12 | sabha
# Processing Record 2 of Set 12 | ranong
# Processing Record 3 of Set 12 | lavrentiya
# Processing Record 4 of Set 12 | elektrougli
# Processing Record 5 of Set 12 | mana
# Processing Record 6 of Set 12 | suileng
# Processing Record 7 of Set 12 | coruripe
# Processing Record 8 of Set 12 | orlik
# Processing Record 9 of Set 12 | alta floresta
# Processing Record 10 of Set 12 | marabba
# Processing Record 11 of Set 12 | henties bay
# Processing Record 12 of Set 12 | warrnambool
# Processing Record 13 of Set 12 | manfredonia
# Processing Record 14 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 15 of Set 12 | walvis bay
# Processing Record 16 of Set 12 | dangriga
# Processing Record 17 of Set 12 | cuenca
# Processing Record 18 of Set 12 | las vegas
# Processing Record 19 of Set 12 | ullapool
# Processing Record 20 of Set 12 | tubmanburg
# Processing Record 21 of Set 12 | flinders
# Processing Record 22 of Set 12 | waterloo
# Processing Record 23 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 24 of Set 12 | mnogovershinnyy
# Processing Record 25 of Set 12 | mao
# Processing Record 26 of Set 12 | imperial
# Processing Record 27 of Set 12 | otradnoye
# Processing Record 28 of Set 12 | huanren
# Processing Record 29 of Set 12 | presidencia roque saenz pena
# Processing Record 30 of Set 12 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 31 of Set 12 | buncrana
# Processing Record 32 of Set 12 | xining
# Processing Record 33 of Set 12 | krasnozerskoye
# Processing Record 34 of Set 12 | osakarovka
# Processing Record 35 of Set 12 | santa isabel do rio negro
# Processing Record 36 of Set 12 | acari
# Processing Record 37 of Set 12 | luanda
# Processing Record 38 of Set 12 | shache
# Processing Record 39 of Set 12 | karratha
# Processing Record 40 of Set 12 | northallerton
# Processing Record 41 of Set 12 | viseu
# Processing Record 42 of Set 12 | vao
# Processing Record 43 of Set 12 | sioux lookout
# Processing Record 44 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 12 | rudnichnyy
# Processing Record 46 of Set 12 | ballarat
# Processing Record 47 of Set 12 | pervomayskoye
# Processing Record 48 of Set 12 | borba
# Processing Record 49 of Set 12 | galle
# Processing Record 50 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 1 of Set 13 | semey
# Processing Record 2 of Set 13 | durban
# Processing Record 3 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 13 | coihaique
# Processing Record 5 of Set 13 | pierre
# Processing Record 6 of Set 13 | hambantota
# Processing Record 7 of Set 13 | padang
# Processing Record 8 of Set 13 | ambalavao
# Processing Record 9 of Set 13 | marataizes
# Processing Record 10 of Set 13 | filingue
# Processing Record 11 of Set 13 | neuquen
# Processing Record 12 of Set 13 | panzhihua
# Processing Record 13 of Set 13 | manggar
# Processing Record 14 of Set 13 | haines junction
# Processing Record 15 of Set 13 | pangnirtung
# Processing Record 16 of Set 13 | kelso
# Processing Record 17 of Set 13 | jurm
# Processing Record 18 of Set 13 | kahului
# Processing Record 19 of Set 13 | marsh harbour
# Processing Record 20 of Set 13 | twentynine palms
# Processing Record 21 of Set 13 | mayahi
# Processing Record 22 of Set 13 | chumikan
# Processing Record 23 of Set 13 | chaohu
# Processing Record 24 of Set 13 | rudbar
# Processing Record 25 of Set 13 | kushmurun
# Processing Record 26 of Set 13 | yemelyanovo
# Processing Record 27 of Set 13 | kodiak
# Processing Record 28 of Set 13 | iquique
# Processing Record 29 of Set 13 | ibra
# Processing Record 30 of Set 13 | kalundborg
# Processing Record 31 of Set 13 | sainte-martine
# Processing Record 32 of Set 13 | santiago
# Processing Record 33 of Set 13 | ust-barguzin
# Processing Record 34 of Set 13 | ziniare
# Processing Record 35 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 13 | atar
# Processing Record 37 of Set 13 | paracuru
# Processing Record 38 of Set 13 | shubarshi
# Processing Record 39 of Set 13 | kampot
# Processing Record 40 of Set 13 | voyvozh
# Processing Record 41 of Set 13 | baneh
# Processing Record 42 of Set 13 | peterhead
# Processing Record 43 of Set 13 | sungaipenuh
# Processing Record 44 of Set 13 | kinanah
# City not found. Skipping...
# Processing Record 45 of Set 13 | lensk
# Processing Record 46 of Set 13 | zhangjiakou
# Processing Record 47 of Set 13 | ouallam
# Processing Record 48 of Set 13 | qasigiannguit
# Processing Record 49 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 50 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 1 of Set 14 | sabaudia
# Processing Record 2 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 14 | fredericksburg
# Processing Record 4 of Set 14 | xiaoweizhai
# Processing Record 5 of Set 14 | cairns
# Processing Record 6 of Set 14 | okmulgee
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 594

# %%
# IMPORTANT
# If you didn't get more than 500 cities, run the code to generate random latitude and longitude combinations and all the code below it. Or increase the size of the latitude and longitude combinations.

# NOTE
# For more information about the try-except blocks, see the documentation on errors and exceptions (Links to an external site.).
# https://docs.python.org/3.7/tutorial/errors.html

# %% [markdown]
# # 6.2.7 Create a DataFrame of City Weather Data

# %%
# Our next steps will entail converting the array of dictionaries to a DataFrame, ensuring the columns are in the correct order, and exporting the DataFrame to a comma-separated (CSV) file.

# REWIND
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Omboue  -1.5746    9.2618     78.66        89         100
# 1            Khandyga  62.6667  135.6000     30.34        78         100
# 2  Puerto Del Rosario  28.5004  -13.8627     64.15        63          75
# 3            Berlevag  70.8578   29.0864     37.20        97          83
# 4         Port Alfred -33.5906   26.8910     72.84        52         100
# 5             Ushuaia -54.8000  -68.3000     44.26        81         100
# 6            Bengkulu  -3.8004  102.2655     76.68        86          93
# 7               Airai  -8.9266  125.4092     71.58        64          39
# 8           Caravelas -17.7125  -39.2481     74.32        77           0
# 9              Torbay  47.6666  -52.7314     44.58        93         100
#
#    Wind Speed Country                 Date
# 0        4.07      GA  2022-04-21 01:22:23
# 1        3.96      RU  2022-04-21 01:22:24
# 2       25.32      ES  2022-04-21 01:22:24
# 3        2.91      NO  2022-04-21 01:22:25
# 4        8.05      ZA  2022-04-21 01:22:25
# 5       21.85      AR  2022-04-21 01:17:47
# 6        4.12      ID  2022-04-21 01:22:26
# 7        3.78      TL  2022-04-21 01:22:26
# 8        5.41      BR  2022-04-21 01:22:27
# 9       17.27      CA  2022-04-21 01:22:27

# %%
# Reorder the columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed, so they are easy to read.

# REWIND
# Recall that to reorder the columns, we assign a variable to an array of the columns in the order we want them to appear:

# new_column_order = ["column2", "column4", "column1"]

# Then, we assign a new or the same DataFrame with new column order:

# df = df[new_column_order]

new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#                    City Country                 Date      Lat       Lng  \
# 0                Omboue      GA  2022-04-21 01:22:23  -1.5746    9.2618
# 1              Khandyga      RU  2022-04-21 01:22:24  62.6667  135.6000
# 2    Puerto Del Rosario      ES  2022-04-21 01:22:24  28.5004  -13.8627
# 3              Berlevag      NO  2022-04-21 01:22:25  70.8578   29.0864
# 4           Port Alfred      ZA  2022-04-21 01:22:25 -33.5906   26.8910
# ..                  ...     ...                  ...      ...       ...
# 589            Sabaudia      IT  2022-04-21 01:39:31  41.3003   13.0282
# 590      Fredericksburg      US  2022-04-21 01:37:24  38.3032  -77.4605
# 591         Xiaoweizhai      CN  2022-04-21 01:39:32  26.1903  107.5125
# 592              Cairns      AU  2022-04-21 01:37:24 -16.9167  145.7667
# 593            Okmulgee      US  2022-04-21 01:39:32  35.6234  -95.9605
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       78.66        89         100        4.07
# 1       30.34        78         100        3.96
# 2       64.15        63          75       25.32
# 3       37.20        97          83        2.91
# 4       72.84        52         100        8.05
# ..        ...       ...         ...         ...
# 589     61.79        72         100       10.11
# 590     55.62        51           0        6.91
# 591     65.48        79         100        6.73
# 592     85.06       100          75        8.05
# 593     75.31        78           0        9.22
#
# [594 rows x 9 columns]

# %%
# Lastly, create an output file to save the DataFrame as a CSV in a new folder for that file.

# In World_Weather_Analysis folder, create a new folder called "weather_data." 
# Add the following code to a new cell, run the cell, then confirm your CSV file is in the folder.

# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# The last line in the code block will export the DataFrame to a CSV file, with the index label (or column A) header as "City_ID." If we ever need to export the CSV file to a DataFrame, that header will be present in the DataFrame.

# %% [markdown]
# # Per Module 6.2.7: at this point, update GitHub repository (steps below):

# %% [markdown]
# # Modify the .gitignore File

# %%
# We don't want the config.py file containing the API key to be exposed to the public on GitHub, as this would mean anyone could copy and use our API key, possibly causing us to incur charges.

# When we type git status in the command line, we can see all the files we have created so far that are untracked.
